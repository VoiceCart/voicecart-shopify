# %%
import pandas as pd
df = pd.read_parquet('getvoicecart.myshopify.com.parquet')
display(df)
# Out:
#                                         id  \
# 0      gid://shopify/Product/9825594736906
# 1      gid://shopify/Product/9825594835210
# 2      gid://shopify/Product/9825632616714
# 3      gid://shopify/Product/9826595832074
# 4      gid://shopify/Product/9826595963146
# ...                                    ...
# 13223  gid://shopify/Product/9827733537034
# 13224  gid://shopify/Product/9827733602570
# 13225  gid://shopify/Product/9827733700874
# 13226  gid://shopify/Product/9827733733642
# 13227  gid://shopify/Product/9845346763018
#
#                                                     name             brand  \
# 0                                        Example T-Shirt              Acme
# 1                                          Example Pants              Acme
# 2                                        Testing product      GetVoiceCart
# 3                 Garlic Oil - Vegetarian Capsule 500 mg  Sri Sri Ayurveda
# ...
